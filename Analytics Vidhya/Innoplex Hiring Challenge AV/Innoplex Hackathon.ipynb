# %%
import re
import nltk
from bs4 import BeautifulSoup
# from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn import metrics
from IPython.display import display
from nltk import WordPunctTokenizer
import pandas as pd
import feather
import gensim
from gensim.models import Word2Vec
import numpy as np
import multiprocessing
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.test.utils import datapath, get_tmpfile
from sklearn.metrics import f1_score,classification_report
from fastai.imports import *
from fastai.structured import *
# from stop_words import get_stop_words
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# from fastai.nlp import *
from scipy.sparse import csc_matrix
import itertools
import os
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from sklearn.metrics import confusion_matrix
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.preprocessing import text, sequence
from keras import utils
from sklearn.metrics import confusion_matrix 
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.pipeline import FeatureUnion 
from sklearn.naive_bayes import BernoulliNB
import xgboost as xgb
from sklearn.metrics import f1_score, accuracy_score
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import SGDClassifier

# %%
# !pip install wordcloud
# Out:
# ...
# WARNING: You are using pip version 19.1.1, however version 19.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
 def tokenize(self, s):
        return s.split(self._string)

# %%
# !pip install keras
# Out:
# ...
# WARNING: You are using pip version 19.1.1, however version 19.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
df = pd.read_csv("C:\Kaggle\Data_Inn.csv",low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a1e9167c6809> in <module>
# ----> 1 df = pd.read_csv("C:\Kaggle\Data_Inn.csv",low_memory=False)
#
# NameError: name 'pd' is not defined

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000,"display.max_columns",1000):
        display(df)

# %%
display_all(df)
# Out:
#                                    unique_hash  \
# 0     2e180be4c9214c1f5ab51fd8cc32bc80c9f612e0
# 1     9eba8f80e7e20f3a2f48685530748fbfa95943e4
# 2     fe809672251f6bd0d986e00380f48d047c7e7b76
# 3     bd22104dfa9ec80db4099523e03fae7a52735eb6
# 4     b227688381f9b25e5b65109dd00f7f895e838249
# 5     a043780c757966243779bf3c0d11bf6eef721971
# 6     be5a13376933a7f9bbf8e801c31691092f63260a
# 7     08c3c0c702fc97d290204b37798ac62005da5626
# 8     8fd3d7ad80791c9343e5cf8a83bd1adf6577d516
# 9     793c5af7cc8332df17eb602247d886fbd1c80f89
# 10    127a56fe52ebb4ac4bd7c44882b38c90b309b0d1
# 11    c012af0fb7ffdbd0cf26564666f344f136bde78f
# 12    9e7ba64f3370ad7b6214677051ad542c45a667bb
# 13    497b861718dcea8618daa71fff8ccdeff2e5b161
# 14    4448be865036bcb6154ca03a3b101ea3a9ba4dac
# 15    aa8baf1777c68498006a91e2dde76cea8d481f23
# 16    abbe2c5ec2d09c903eea188d56dd1f0ccfa2be5c
# 17    fb054b0af1d68a71577430858e6dbe4162d269b3
# 18    81d3b59febf33f7099315d8a06402a84a4083113
# ...

# %% [markdown]
# As We can see from the data there are four columns we need to predict the sentiment column with text and drug name column

# %%
def train_cats(df):
    for n,c in df.items():
        if is_string_dtype(c): df[n] = c.astype('category').cat.as_ordered()
train_cats(df)

# %% [markdown]
# First converting the drug column to categorical using the train cats function taken from fastai

# %%
df.drug.cat.categories
# Out:
# Index(['afatinib', 'aflibercept', 'alecensa', 'alectinib', 'alectnib',
#        'alemtuzumab', 'alimta', 'almita', 'alunbrig', 'amjevita',
#        ...
#        'tofacitinib', 'trametinib', 'tysabri', 'upadacitinib', 'ustekinumab',
#        'vedolizumab', 'vitrectomy', 'xalkori', 'yervoy', 'zykadia'],
#       dtype='object', length=102)

# %%
df.drug = df.drug.cat.codes

# %%
display_all(df.isnull().sum().sort_index()/len(df))
# Out:
# drug           0.0
# sentiment      0.0
# text           0.0
# unique_hash    0.0
# dtype: float64

# %%
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9_]+'
pat2 = r'https?://[^ ]+'
combined_pat = r'|'.join((pat1, pat2))
www_pat = r'www.[^ ]+'
negations_dic = {"isn't": "is not", "aren't": "are not", "wasn't": "was not", "weren't": "were not",
                 "haven't": "have not", "hasn't": "has not", "hadn't": "had not", "won't": "will not",
                 "wouldn't": "would not", "don't": "do not", "doesn't": "does not", "didn't": "did not",
                 "can't": "can not", "couldn't": "could not", "shouldn't": "should not", "mightn't": "might not",
                 "mustn't": "must not"}

neg_pattern = re.compile(r'\b(' + '|'.join(negations_dic.keys()) + r')\b')

def cleaning_data(text):
    soup = BeautifulSoup(text)
    souped = soup.get_text()
#     for i in unicode_dic:
#         souped= souped.replace(i, unicode_dic[i])
    stripped = re.sub(combined_pat, '', souped)
    stripped = re.sub(www_pat, '', stripped)
    stripped = re.sub(r'RT', '', stripped)
    lower_case = stripped.lower()
    neg_handled = neg_pattern.sub(lambda x: negations_dic[x.group()], lower_case)
    letters_only = re.sub("[^a-zA-Z]", " ", neg_handled)
    #Removal of stopwords
    token_conv = nltk.word_tokenize(letters_only)
    for i in range(len(token_conv)):
        token_conv[i] = nltk.stem.WordNetLemmatizer().lemmatize(token_conv[i], 'v')
    words_join = (" ".join(token_conv)).strip()
    words = [x for x in tok.tokenize(words_join) if len(x) > 1]
    return (" ".join(words)).strip()

# %% [markdown]
# Cleaning the text data by removing stopwards, lemmatization, handling negations as its a sentimental analysis its Important

# %%
len_df = len(df.text)
nums = [0,len_df]
clean_text = []
for i in range(nums[0], nums[1]):
    clean_text.append(cleaning_data(df['text'][i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-63f264d24a25> in <module>()
# ----> 1 len_df = len(df.text)
#       2 nums = [0,len_df]
#       3 clean_text = []
#       4 for i in range(nums[0], nums[1]):
#       5     clean_text.append(cleaning_data(df['text'][i]))
#
# NameError: name 'df' is not defined

# %%
df['text']  = pd.DataFrame(data=clean_text)

# %%
df.head()
# Out:
#                                 unique_hash  \
# 0  2e180be4c9214c1f5ab51fd8cc32bc80c9f612e0
# 1  9eba8f80e7e20f3a2f48685530748fbfa95943e4
# 2  fe809672251f6bd0d986e00380f48d047c7e7b76
# 3  bd22104dfa9ec80db4099523e03fae7a52735eb6
# 4  b227688381f9b25e5b65109dd00f7f895e838249
#
#                                                 text  drug  sentiment
# 0  autoimmune diseases tend to come in cluster as...    38          2
# 1  can completely understand why you want to try ...    38          2
# 2  interest that it only target receptors rather ...    35          2
# 3  very interest grand merci now wonder where lem...    64          2
# 4  hi everybody my latest mri result for brain an...    38          1

# %%
os.makedirs('tmp',exist_ok=True)
df.to_feather('C:/Kaggle/tmp/Data_Inn-raw1')

# %%
df = feather.read_dataframe('C:/Kaggle/tmp/Data_Inn-raw')

# %%
display(df.tail().T)
# Out:
#                                                           5274  \
# unique_hash           5b5d129f3bab30fbb4740540a16856907657f005
# text         hi bee thank for the update and the good news ...
# drug                                                         6
# sentiment                                                    0
#
#                                                           5275  \
# unique_hash           1aa7dde5dc5249ebc3490c1fbac6ca6df48753a2
# text         have you have blood test do to check your leve...
# drug                                                        31
# sentiment                                                    2
#
#                                                  5276  \
# unique_hash  e9159c3f836f453f5f133008d40b7e65f9e70a42
# text          all the best to your husband and family
# drug                                               66
# sentiment                                           2
#
# ...

# %%
tokenize = nltk.data.load('tokenizers/punkt/english.pickle')
def review_to_wordlist(review, remove_stopwords=False):
    """
    Convert a review to a list of words. Removal of stop words is optional.
    """
    # remove non-letters

    #convert to lower case and split at whitespace
    words = review.lower().split()

    # remove stop words (false by default)
    if remove_stopwords:
        stop_words = get_stop_words('english')
        words = [w for w in words if not w in stop_words]

    return words

# %%
cores = multiprocessing.cpu_count()
print(cores)
# model_name = 'deps_words'
# # Set values for various word2vec parameters
num_features = 200    # Word vector dimensionality
# min_word_count = 30   # Minimum word count
# num_workers = cores       # Number of threads to run in parallel
# context = 8          # Context window size
# downsampling = 1e-3   # Downsample setting for frequent words
# epochs = 50

# if not os.path.exists(model_name):
#      # Initialize and train the model (this will take some time)
#         model = Word2Vec(train_sentences, workers=num_workers, \
#                  size=num_features, min_count = min_word_count, \
#                  window = context, sample = downsampling,sg=0,iter=epochs)

#      # If you don't plan to train the model any further, calling
#      # init_sims will make the model much more memory-efficient.
#      #     model.init_sims(replace=True)

#      # It can be helpful to create a meaningful model name and
#      # save the model for later use. You can load it later using Word2Vec.load()
#      model.save(model_name)
# else:
glove_file = datapath('C:/Kaggle/glove.6B.200d.txt')
tmp_file = get_tmpfile("test_word2vec.txt")
_ = glove2word2vec(glove_file, tmp_file)
model = KeyedVectors.load_word2vec_format(tmp_file)

# %% [markdown]
# Here we are using glove pretrained embbeding to convert our text to embeddings,we use word2vec here to covert glove format to Word2vec

# %%
model.wv.most_similar("not",topn=20)
model.wv.most_similar("love")

# %%
index2word_set = set(model.wv.index2word)

# %%
def makeFeatureVec(words, model, num_features):
#     Function to average all of the word vectors in a given
    # paragraph
    #
    # Pre-initialize an empty numpy array (for speed)
    featureVec = np.zeros((num_features,),dtype=np.float64)
    nwords = 0
    #
    # Index2word is a list that contains the names of the words in
    # the model's vocabulary. Convert it to a set, for speed
    #
    # Loop over each word in the review and, if it is in the model's
    # vocaublary, add its feature vector to the total
    for word in words:
        if word in index2word_set:
#             print(word)
            nwords = nwords + 1
#             print(nwords)
            featureVec = np.add(featureVec,model.wv[word])
    if nwords > 0:
    # Divide the result by the number of words to get the average
        featureVec = np.divide(featureVec,nwords)
    return featureVec

# %%
def getAvgFeatureVecs(reviews, model, num_features):
    # Given a set of reviews (each clean_train_reviews = []

    #trainDataVecs = getAvgFeatureVecs(clean_train_reviews, model, num_features)one a list of words), calculate
    # the average feature vector for each one and return a 2D numpy array
    #
    # Initialize a counter
    counter = 0
    #
    # Preallocate a 2D numpy array, for speed
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype=np.float32)
    #
    # Loop through the reviews
    for review in reviews:
#         if counter%100 == 0:
#             print("Review %d of %d" % (counter, len(reviews))
        reviewFeatureVecs[counter] = makeFeatureVec(review, model,num_features)
        counter = counter + 1
    return reviewFeatureVecs

# %% [markdown]
# We use Word2vec embeddings here

# %%
# display_all(df.isnull().sum().sort_index()/len(df)) 
# y = df['sentiment']
# print(y.value_counts())
# df1 = df.drop(['unique_hash','sentiment'],axis=1)
# df1.head()

# %%
df_test = pd.read_csv("C:/Kaggle/test_Inn.csv")
len_df = len(df_test.text)
nums = [0,len_df]
clean_text = []
for i in range(nums[0], nums[1]):
    clean_text.append(cleaning_data(df_test['text'][i]))
df_test['text'] = pd.Dataframe(data=clean_text)
# Out:
# D:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file D:\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# D:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# ...

# %%
df_zero = df.loc[df['sentiment'] == 0]
df_one  = df.loc[df['sentiment']== 1]
df_two = df.loc[df['sentiment'] == 2]
df_one = df_one[0:617]
df_two =df_two[0:617]
df_int = df
# df_zero['drug'].value_counts()
# df_one['drug'].value_counts()
# df_two['drug'].value_counts()

# %% [markdown]
# UnderSampling to Train

# %%
y = df_int['sentiment']
df_int = df_int.drop(['unique_hash','sentiment'],axis=1)

# %%
## Number of words in the text ##
df_int["num_words"] = df_int['text'].apply(lambda x: len(str(x).split()))
df_test["num_words"] = df_test["text"].apply(lambda x: len(str(x).split()))

# %%
## Number of unique words in the text ##
df_int["num_unique_words"] = df_int["text"].apply(lambda x: len(set(str(x).split())))
df_test["num_unique_words"] = df_test["text"].apply(lambda x: len(set(str(x).split())))

# %%
## Number of characters in the text ##
df_int["num_chars"] = df_int["text"].apply(lambda x: len(str(x)))
df_test["num_chars"] = df_test["text"].apply(lambda x: len(str(x)))

# %%
## Number of stopwords in the text ##
df_int["num_stopwords"] = df_int["text"].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS]))
df_test["num_stopwords"] =df_test["text"].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS]))

# %%
## Number of punctuations in the text ##
# df_int["num_punctuations"] =df['question_text'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]) )
# test_df["num_punctuations"] =test_df['question_text'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]) )

# %%
## Number of title case words in the text ##
# train_df["num_words_upper"] = train_df["question_text"].apply(lambda x: len([w for w in str(x).split() if w.isupper()]))
# test_df["num_words_upper"] = test_df["question_text"].apply(lambda x: len([w for w in str(x).split() if w.isupper()]))

# %%
## Number of title case words in the text ##
# df_int["num_words_title"] = df_int["text"].apply(lambda x: len([w for w in str(x).split() if w.istitle()]))
# df_test["num_words_title"] = df_test["text"].apply(lambda x: len([w for w in str(x).split() if w.istitle()]))

# %%
## Average length of the words in the text ##
df_int["mean_word_len"] = df_int["text"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))
df_test["mean_word_len"] = df_test["text"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))

# %%
# df_int = df_int.drop(['num_words_title','num_words_title]'],axis=1)
# df_test = df_test.drop(['num_words_title'],axis=1)

# %%
df_int['drug']=df_int['drug'].astype(str)
df_int['num_chars']=df_int['num_chars'].astype(str)
df_int['num_stopwords']=df_int['num_stopwords'].astype(str)
df_int['num_words']=df_int['num_words'].astype(str)
df_int['num_unique_words']=df_int['num_unique_words'].astype(str)
df_int['mean_word_len']=df_int['mean_word_len'].astype(str)

# %%
df_test['drug']=df_test['drug'].astype(str)
df_test['num_chars']=df_test['num_chars'].astype(str)
df_test['num_stopwords']=df_test['num_stopwords'].astype(str)
df_test['num_words']=df_test['num_words'].astype(str)
df_test['num_unique_words']=df_test['num_unique_words'].astype(str)
df_test['mean_word_len']=df_test['mean_word_len'].astype(str)

# %% [markdown]
# Here we create more features to tell us whats unique in every sentiment are people using punctuations for some sentiments using a Lot of words etc

# %%
def build_preprocessor(field):
    field_idx = list(df_int.columns).index(field)
    return lambda x: default_preprocessor(x[field_idx])

# %%
default_preprocessor = CountVectorizer().build_preprocessor()

# %%
vectorizer = FeatureUnion([
    ('text', TfidfVectorizer(stop_words='english',
        ngram_range=(1, 2),
        max_features=None,
        preprocessor=build_preprocessor('text'))),
    ('drug', CountVectorizer(
        token_pattern='\d+',
        preprocessor=build_preprocessor('drug'))),
     ('num_chars', CountVectorizer(
        token_pattern='\d+',
        preprocessor=build_preprocessor('num_chars'))),
     ('num_stopwords', CountVectorizer(
        token_pattern='\d+',
        preprocessor=build_preprocessor('num_stopwords'))),
     ('num_words', CountVectorizer(
        token_pattern='\d+',
        preprocessor=build_preprocessor('num_words'))),
     ('num_unique_words', CountVectorizer(
        token_pattern='\d+',
        preprocessor=build_preprocessor('num_unique_words'))),
     ('mean_word_len', CountVectorizer(
        token_pattern='\d+',
        preprocessor=build_preprocessor('mean_word_len'))),
])

# %% [markdown]
# Here Using FeatureUnion we combine all the numeric and Text features using a CountVectorizer and TFIDFVectorizer

# %% [markdown]
# This Uses a lot of memory so we dont use it

# %%
x_review = X_train.text
x_review_test = df_test.text
x_review_valid = X_valid.text
clean_valid_reviews = []
clean_test_reviews = []
clean_train_reviews = []

for review in x_review:
    clean_train_reviews.append(review_to_wordlist(review,remove_stopwords=True))

for review in x_review_valid:
    clean_valid_reviews.append(review_to_wordlist(review,remove_stopwords=True))

for review in x_review_test:
    clean_test_reviews.append(review_to_wordlist(review,remove_stopwords=True))

    
ValidDataVecs = getAvgFeatureVecs(clean_valid_reviews, model, num_features)
TestDataVecs = getAvgFeatureVecs(clean_test_reviews,model,num_features)
trainDataVecs = getAvgFeatureVecs(clean_train_reviews, model, num_features)

# %% [markdown]
# Creating word2vec Embeddings

# %%
def print_score(m):
    res = [f1_score(y_train,m.predict(X_train),average=None),f1_score(y_valid,m.predict(X_valid),average=None),
            m.score(X_train, y_train), m.score(X_valid, y_valid)]
    if hasattr(m,'oob_score'): res.append(m.oob_score_)
    return res

# %%
stopwords = set(STOPWORDS)

# %%
def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
# show_wordcloud(df_zero['text'])
# show_wordcloud(df_one['text'])
show_wordcloud(df_two['text'])

# %% [markdown]
# Doing some EDA

# %%
trn_doc = veczr.fit_transform(X_train['text'].values.tolist())
val_doc = veczr.transform(X_valid.text)
trn_doc1 = veczr1.fit_transform(X_train.text)
val_doc1 = veczr1.transform(X_valid.text)
trn_doc = pd.DataFrame(data=trn_doc)
val_doc = pd.DataFrame(data=val_doc)
trn_doc = trn_doc.reset_index(drop=True,inplace=True).join(X_train['drug'].reset_index(drop=True,inplace=True), how='left')
val_doc = val_doc.reset_index(drop=True,inplace=True).join(X_valid['drug'].reset_index(drop=True,inplace=True), how='left')

# %% [markdown]
# Prepare Data For Training

# %%
trn_doc.shape
# Out:
# (1480, 50000)

# %%
df_test1 = df_test.drop(['unique_hash'],axis=1)
df_test1.head()
# Out:
#                                                 text        drug num_words  \
# 0  256 (previously stable on natalizumab), with 5...  fingolimod        10
# 1  On fingolimod and have been since December 201...  fingolimod        27
# 2  Apparently it's shingles! :-/ I do have a few ...      humira       181
# 3  If the Docetaxel doing once a week x3 weeks th...    tagrisso       160
# 4  CC, Stelara worked in a matter of days for me....     stelara       525
#
#   num_unique_words num_chars num_stopwords      mean_word_len
# 0               10        72             3                6.3
# 1               27       146            17  4.444444444444445
# 2              142      1035            77  4.718232044198895
# 3              126       918            34              4.625
# 4              305      3168           215  5.013333333333334

# %%
train_cats(df_test1)
df_test1.drug = df_test1.drug.cat.codes

# %%
df_test1['drug']=df_test1['drug'].astype(str)

# %%
test_doc = vectorizer.transform(df_test1.values)

# %%
test_doc.shape
# Out:
# (2924, 464979)

# %%
tfidf_vect = TfidfVectorizer(analyzer='word', stop_words=None, token_pattern='(?u)\\b\\w\\w+\\b', ngram_range=(1, 1), max_df=1.0, 
                             min_df=3, max_features=None, binary=False, norm='l2', use_idf=True, smooth_idf=True, sublinear_tf=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-2625f76b8a6d> in <module>()
# ----> 1 X_train.columns
#
# D:\Anaconda3\lib\site-packages\scipy\sparse\base.py in __getattr__(self, attr)
#     684             return self.getnnz()
#     685         else:
# --> 686             raise AttributeError(attr + " not found")
#     687
#     688     def transpose(self, axes=None, copy=False):
#
# AttributeError: columns not found

# %%
# m = BernoulliNB(alpha=1e-8)
# m.fit(df_int,y)
sgd = SGDClassifier(loss='log', max_iter=200, random_state=0, class_weight='balanced')
# ovr = OneVsRestClassifier(sgd)
# ovr.fit(X_train, y_train)


# m = RandomForestClassifier(class_weight='balanced',n_estimators=40,n_jobs=-1,max_features=10000,oob_score=True,min_samples_leaf=3)
# m.fit(X_train,y_train)
ovr = OneVsRestClassifier(sgd)
ovr.fit(X_train, y_train)
y_pred_class =ovr.predict(X_valid)
print('f1_score       :', f1_score(y_valid,y_pred_class, average='macro'))
print('accuracy score :', accuracy_score(y_valid, y_pred_class))
# print(m.oob_score_)
# # m = xgb.XGBClassifier(objective='mutli:softprob', n_estimators=100, colsample_bytree=0.8, 
#                         subsample=0.8, nthread=10, learning_rate=0.1, silent=False)
# m.fit(df_int, y)
# Out:
# f1_score       : 0.4047522489284308
# accuracy score : 0.6477272727272727

# %% [markdown]
# f1_score with Naive SGD and OneVRest Classifier

# %%
fi = rf_feat_importance(m,df_int.drop(['text'],axis=1))
fi
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-174-ddd0ec108c3b> in <module>()
# ----> 1 fi = rf_feat_importance(m,df_int.drop(['text'],axis=1))
#       2 fi
#
# C:\Kaggle\fastai\structured.py in rf_feat_importance(m, df)
#     452
#     453 def rf_feat_importance(m, df):
# --> 454     return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
#     455                        ).sort_values('imp', ascending=False)
#     456
#
# D:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in feature_importances_(self)
#     366         feature_importances_ : array, shape = [n_features]
#     367         """
# --> 368         check_is_fitted(self, 'estimators_')
#     369
#     370         all_importances = Parallel(n_jobs=self.n_jobs,
#
# D:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
# ...

# %% [markdown]
# checking feature Importances with RF which is a very wrong way as text column isnt very representative here

# %%
fi.plot('cols', 'imp', figsize=(10,6), legend=False);

# %%
def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)

# %%
plot_fi(fi)

# %% [markdown]
# Using ELI5 TO check top features for every sentiments very good and effective thing

# %%
import eli5
eli5.show_weights(ovr,vec=vectorizer)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
# ...

# %%
y_pred = m.predict(X_valid)
print((y_pred.T==y_valid).mean())
print(classification_report(y_valid,y_pred))
print(confusion_matrix(y_valid,y_pred))
# Out:
# 0.5121293800539084
#              precision    recall  f1-score   support
#
#           0       0.51      0.57      0.54       110
#           1       0.54      0.53      0.54       136
#           2       0.48      0.44      0.46       125
#
# avg / total       0.51      0.51      0.51       371
#
# [[63 22 25]
#  [30 72 34]
#  [31 39 55]]

# %% [markdown]
# final prediction with xgboost

# %%
trainDataVecs = pd.DataFrame(data=trainDataVecs)
Final_df = trainDataVecs.reset_index(drop=True).join(X_train['drug'].reset_index(drop=True), how='left')
m = RandomForestClassifier(n_estimators=100,max_features=0.5)
m.fit(Final_df, y_train)
ValidDataVecs = pd.DataFrame(data=ValidDataVecs)
Final_valid = ValidDataVecs.reset_index(drop=True).join(X_valid['drug'].reset_index(drop=True), how='left')
TestDataVecs = pd.DataFrame(data=TestDataVecs)

# %% [markdown]
# Traning with Word2vec Pretrained vectors gives a slight improvement

# %%
print(m.score(trainDataVecs,y_train))
print(m.score(ValidDataVecs,y_valid))
y_pred = m.predict(trainDataVecs)
y1_pred = m.predict(Final_valid)
print((y1_pred.T==y_valid).mean())
# print(classification_report(y_train,y_pred))
print(classification_report(y_valid,y1_pred))

# %%
Final_test = TestDataVecs.reset_index(drop=True).join(df_test['drug'].reset_index(drop=True), how='left')
train_cats(test_doc)
test_doc.drug = test_doc.drug.cat.codes
result = ovr.predict(test_doc)
out = pd.DataFrame(data={"unique_hash":df_test["unique_hash"],"sentiment":result})
out.dropna(how='all', axis='columns')
out.to_csv("C:/Kaggle/out0.csv")
out['sentiment'].value_counts()
# Out:
# 2    2749
# 0     101
# 1      74
# Name: sentiment, dtype: int64

# %%
df_int.shape
# Out:
# (1851, 54182)

# %% [markdown]
# First Ever Hackathon so made some mistakes but in the End Still able to get 220 Rank on PVT and Public LeaderBoard with just the Naive Models thats top 10% for this Competition , Could have tried and used Better Models such as BERT,XLNET to train as the data was heavily depenedent on names of drugs being used in the sentences and its relation with the Drug Column the Feature Engineering and Word2vec helped a lot
